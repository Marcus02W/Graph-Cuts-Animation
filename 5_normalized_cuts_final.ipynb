# %%
from manim import *
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Manim Community v0.18.0

# %%
config.media_embed = True
config.tex_compiler = "pdflatex"

# %%
# List of nodes
vertices = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# Create edges between adjacent nodes
edges = [(i, i + 1) for i in range(1, 9) if not i % 3 == 0] + [(j, j + 3) for j in range(1, 7)] + [(k, k + 4) for k in [1, 2, 4, 5]] + [(l, l + 2) for l in [2, 3, 5, 6]]

# Groups of nodes with the same color
group1_nodes = [1, 2, 4]
group2_nodes = [3, 5, 6, 7, 8, 9]
acc_group1_nodes = [1]

# Colors for the groups
group1_color = '#318ab3'
group2_color = '#68228B'

# Create the graph with manual positioning and color configuration
layout = {
    1: np.array([-1, 1, 0]),
    2: np.array([0, 1, 0]),
    3: np.array([1, 1, 0]),
    4: np.array([-1, 0, 0]),
    5: np.array([0, 0, 0]),
    6: np.array([1, 0, 0]),
    7: np.array([-1, -1, 0]),
    8: np.array([0, -1, 0]),
    9: np.array([1, -1, 0]),
}

# Adjustment of edges in the graph 1
vertex_config1 = {
    node: {"fill_color": group1_color, "stroke_color": GREY, "stroke_width": 2} if node in [2, 4]
    else ({"fill_color": group1_color, "stroke_color": YELLOW, "stroke_width": 2} if node in [1] else {"fill_color": group2_color, "stroke_color": GREY, "stroke_width": 2})
    for node in vertices
}
# Adjustment of edges in the graph 2
vertex_config2 = {
    node: {"fill_color": group1_color, "stroke_color": YELLOW,"stroke_width": 2} if node in group1_nodes else {"fill_color": group2_color, "stroke_color": GREY, "stroke_width": 2}
    for node in vertices
}

# Adjustment of edges in the graph
edge_config = {
    edge: {"stroke_color": group1_color} if edge in [(1, 2), (1, 4), (1, 5)] else {"stroke_color": GREY} 
    for edge in edges
}

# Es wird ein neuer Graph erstellt, an dem veranschaulicht wird
updated_edge_config = {
    edge: {"stroke_color": group1_color} if edge in [(1, 2), (1, 4), (1, 5), (2,3), (2,6), (2,5),(2,4), (4,5), (4,8),(4,7)] else {"stroke_color": GREY} 
    for edge in edges
}

# function for creating edge labels
def create_label(number, radius):
    white_circle = Circle(color=WHITE, fill_opacity=1, radius=radius)
    black_number = Text(str(number), color=WHITE).scale(0.3)
    label = VGroup(white_circle, black_number)
    return label

# %%
# NumPy calculation of the association and the normalized cuts
weak_acc=1+1+0.6
weak_acc_2=(13*1)+(0.6*7)
strong_acc=1+1+1+(0.6*7)
strong_acc_2=(10*1)+(0.6*7)
cut_ab_1 = 1+1+0.6
cut_ab_2 = (0.6*7)
NCut_1 = (cut_ab_1/weak_acc)+(cut_ab_1/weak_acc_2)
NCut_2 = (cut_ab_2/strong_acc)+(cut_ab_2/strong_acc_2)

# %%
# Create graphs in Manim
g = Graph(vertices, edges, layout=layout, vertex_config=vertex_config1, edge_config=edge_config)
new_g = Graph(vertices, edges, layout=layout, vertex_config=vertex_config2, edge_config=updated_edge_config)

class Scene_5(Scene):
    def construct(self):
        # Add headlines to the video
        text01 = Text("How do we solve this problem?").scale(0.8)
        self.play(Write(text01))
        self.play(text01.animate.to_edge(UP))
        self.wait(5)

        #latex formula
        acc = MathTex(r"assoc(V_a, V) = \sum_{u \in V_A} \forall v \in V (w(u, v))").scale(0.6)
        acc.shift(UP*2)
        self.play(Write(acc))
        weak = MathTex("Weak\ assoc(V_a,V)= 2.6").scale(0.5).shift(DOWN*3+LEFT*3)
        strong = MathTex("Strong\ assoc(V_a,V)= 7.2").scale(0.5).shift(DOWN*3+RIGHT*3)

        #Move and scale graphs
        g.move_to(ORIGIN)
        new_g.move_to(ORIGIN)
        g.scale(1.5)
        new_g.scale(1.5)
        g.shift(DOWN+LEFT*3)
        new_g.shift(DOWN+RIGHT*3)
        
        # Graph labels
        v_a_1 = Text("V_a", color=YELLOW).scale(0.3).shift(LEFT*5)
        v_b_1 = Text("V_b", color=GREY).scale(0.3).shift(LEFT*1+DOWN*2)
        v_a_2 = Text("V_a", color=YELLOW).scale(0.3).shift(RIGHT*1)
        v_b_2 = Text("V_b", color=GREY).scale(0.3).shift(RIGHT*5+DOWN)
        self.wait(3)
        self.play(Create(g),Create(new_g),Write(v_a_1),Write(v_b_1),Write(v_a_2),Write(v_b_2),)
        
        # Add a dashed line to the scene
        dashed_line1 = DashedLine(start=LEFT *5+DOWN, end=LEFT*3+ UP *1, color=RED)
        dashed_line2 = DashedLine(start=RIGHT + DOWN *2, end=RIGHT * 4 + UP, color=RED)
        self.play(Create(dashed_line1), Create(dashed_line2))

        #add labels to edges
        graph_list=[g,new_g]
        for graph in graph_list:
            edge_labels = {}
            for edge, edge_obj in graph.edges.items():
                if edge in [(1, 5), (2, 6), (4, 8)]:    
                    label = create_label("0.6, 1", 0.001)
                elif edge in [(2, 3), (2, 5), (4, 5), (4, 7)]:
                    label = create_label("0.6", 0.001)
                elif edge in [(5, 9)]:
                    label = create_label("1,1", 0.001)
                else:
                    label = create_label("1", 0.001)
                label.next_to(edge_obj.get_center(), buff=-0.2)
                edge_labels[edge] = label
            self.play(*[Create(label) for label in edge_labels.values()])
        self.wait(10)

        # Write weak and strong acc
        self.play(Write(weak), Write(strong))
        self.wait(5)

        # Play title
        n_cuts=Text("Normalized Cuts").scale(0.8).to_edge(UP)
        self.play(Transform(text01, n_cuts))
        self.wait(2)

        #Formula
        n_cuts_f = MathTex(r"N_{Cut}(V_A, V_B) = \frac{\text{cut}(V_A, V_B)}{\text{assoc}(V_A, V)} + \frac{\text{cut}(V_A, V_B)}{\text{assoc}(V_B, V)}").scale(0.6).shift(UP*2)
        self.play(Transform(acc, n_cuts_f))
        self.wait(8)

        # Write NCuts 
        weak_acc_text = Text(f"({cut_ab_1}/{weak_acc})+({cut_ab_1}/{weak_acc_2})={NCut_1: .2}").scale(0.4).shift(DOWN*3+LEFT*3)
        strong_acc_text = Text(f"({cut_ab_2}/{strong_acc})+({cut_ab_2}/{strong_acc_2})={NCut_2: .2}").scale(0.4).shift(DOWN*3+RIGHT*3)
        self.play(Transform(weak, weak_acc_text),Transform(strong,strong_acc_text))
        self.wait(6)

# %%
# %manim -pql Scene_5
# Out:
# [02/25/24 17:06:16] INFO     Animation 0 : Partial movie file written in                   ]8;id=82267;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=36631;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\118
#                              5818338_3850402542_223132457.mp4'
# [02/25/24 17:06:17] INFO     Animation 1 : Partial movie file written in                   ]8;id=304545;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=698802;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_1170591975_2468625149.mp4'
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=401750;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=387632;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_1815950923_2402378918.mp4'
#                     INFO     Writing assoc(V_a, V) = \sum_{u \in V_A} \forall v \in V (w(u, ]8;id=644090;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=787105;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py#107\107]8;;\
#                              v)) to media\Tex\e5539499b9ec5522.tex
# [02/25/24 17:06:20] INFO     Animation 3 : Partial movie file written in                   ]8;id=72655;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=332388;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_2917673665_2034583189.mp4'
#                     INFO     Writing Weak\ assoc(V_a,V)= 2.6 to                             ]8;id=787708;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=632942;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py#107\107]8;;\
#                              media\Tex\eda1236107e3c37b.tex
# [02/25/24 17:06:21] INFO     Writing Strong\ assoc(V_a,V)= 7.2 to                           ]8;id=398243;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=601339;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py#107\107]8;;\
#                              media\Tex\de92d738275b4cd9.tex
# [02/25/24 17:06:24] INFO     Animation 4 : Partial movie file written in                   ]8;id=732643;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=814646;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_3891874688_491595292.mp4'
# [02/25/24 17:06:25] INFO     Animation 5 : Partial movie file written in                   ]8;id=755557;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=296973;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_2660824838_1777814940.mp4'
# [02/25/24 17:06:26] INFO     Animation 6 : Partial movie file written in                   ]8;id=756355;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=482274;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_2986923534_1178104512.mp4'
# [02/25/24 17:06:28] INFO     Animation 7 : Partial movie file written in                   ]8;id=201128;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=513675;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_514612580_3216233760.mp4'
# [02/25/24 17:06:31] INFO     Animation 8 : Partial movie file written in                   ]8;id=235299;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=48108;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_1791542080_1853629852.mp4'
# [02/25/24 17:06:32] INFO     Animation 9 : Partial movie file written in                   ]8;id=934990;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=338963;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_780035246_3101501806.mp4'
# [02/25/24 17:06:36] INFO     Animation 10 : Partial movie file written in                  ]8;id=567501;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=174924;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_3680101153_186962600.mp4'
# [02/25/24 17:06:37] INFO     Animation 11 : Partial movie file written in                  ]8;id=176777;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=558785;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_255102487_685780775.mp4'
# [02/25/24 17:06:41] INFO     Animation 12 : Partial movie file written in                  ]8;id=646962;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=457195;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_2793878789_560765158.mp4'
# [02/25/24 17:06:42] INFO     Animation 13 : Partial movie file written in                  ]8;id=25951;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=661970;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_634017564_2276040771.mp4'
#                     INFO     Writing N_{Cut}(V_A, V_B) = \frac{\text{cut}(V_A,              ]8;id=176159;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=95596;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\tex_file_writing.py#107\107]8;;\
#                              V_B)}{\text{assoc}(V_A, V)} + \frac{\text{cut}(V_A,
#                              V_B)}{\text{assoc}(V_B, V)} to media\Tex\35b29a034ff72d8d.tex
# [02/25/24 17:06:47] INFO     Animation 14 : Partial movie file written in                  ]8;id=796557;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=793288;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_2766730001_765092380.mp4'
# [02/25/24 17:06:49] INFO     Animation 15 : Partial movie file written in                  ]8;id=570923;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=298939;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_1563271232_1434516666.mp4'
# [02/25/24 17:07:07] INFO     Animation 16 : Partial movie file written in                  ]8;id=207348;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=967516;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_2882224813_2734242810.mp4'
# [02/25/24 17:07:13] INFO     Animation 17 : Partial movie file written in                  ]8;id=627125;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=488220;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\partial_movie_files\Scene_5\624
#                              642324_3175876194_4099631330.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=37382;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=828262;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=662049;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=397384;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene_file_writer.py#735\735]8;;\
#                              File ready at
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\video
#                              s\Graph-Cuts-Animation\480p15\Scene_5.mp4'
#                     INFO     Rendered Scene_5                                                          ]8;id=873198;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=402274;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 18 animations
# [02/25/24 17:07:14] INFO     Previewed File at:                                                     ]8;id=585444;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\file_ops.py\file_ops.py]8;;\:]8;id=92254;file://c:\Users\Adrian\anaconda3\envs\visualization-manim\lib\site-packages\manim\utils\file_ops.py#227\227]8;;\
#                              'C:\Users\Adrian\DHBW_Coding\Graph-Cuts-Animation\media\videos\Graph-C
#                              uts-Animation\480p15\Scene_5.mp4'
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
